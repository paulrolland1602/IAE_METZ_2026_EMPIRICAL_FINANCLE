# %% [markdown]
# premiers exerices

# %%
print("Hello Word")
# Out:
# Hello Word

# %%
print("Analyse Bourse")
# Out:
# Analyse Bourse

# %% [markdown]
# # Let's go learning pyhton

# %%
# Ceci est un commentaire dans la cellule de code 
#Python est une programmation orienté OBJET. On déf des variables
name = "Paul"
name
# Out:
# 'Paul'

# %%
# la dernière def de la variab le l'emporte
name = "Polo"
name
# Out:
# 'Polo'

# %%
#pour les chiffres on a
age = 26  # INTEGRER dans les nombres entier
print(age)
# Out:
# 26

# %%
pi= 3,14
pi
# Out:
# (3, 14)

# %%
#un dictionnaire c'est CLE VALEUR

prices = {"APPLE":248.04,
          "GOOGLE":328.33,
          "TSLA":437.43}

# %%
prices
# Out:
# {'APPLE': 248.04, 'GOOGLE': 328.33, 'TSLA': 437.43}

# %% [markdown]
# # Comment avoir les données boursières ?
# # En effet on ne va pas recopier à la main des dictionnaires

# %%
prices
# Out:
# {'APPLE': 248.04, 'GOOGLE': 328.33, 'TSLA': 437.43}

# %%
# DONC on utilise les PACKAGES
! pip install yfinance
# YAHOO FINANCE
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import yfinance as yf

# %%
! pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
#la structure d'un projet python
#Une cellule ou on emporte TOUS LES PACKAGES
#Comme ça on a une overview des dépendances

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ticker = "AAPL"

# %%
#pour prendre les données du packages Yfinance on utilise 
# une FONCTION qui est def dans ce package pour EXTRAIRE la donnée
data = yf.download(ticker, start="2020-01-01",progress=False)

# %%
data
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.468246   72.528566   71.223244   71.476585  135480400
# 2020-01-03   71.763733   72.523762   71.539345   71.696175  146322800
# 2020-01-06   72.335548   72.374154   70.634532   70.885464  118387200
# 2020-01-07   71.995354   72.600960   71.775789   72.345204  108872000
# 2020-01-08   73.153481   73.455080   71.698566   71.698566  132079200
# ...                ...         ...         ...         ...        ...
# 2026-01-26  255.410004  256.559998  249.800003  251.479996   55969200
# 2026-01-27  258.269989  261.950012  258.209991  259.170013   49648300
# 2026-01-28  256.440002  258.859985  254.509995  257.649994   41288000
# 2026-01-29  258.279999  259.649994  254.410004  258.000000   67253000
# 2026-01-30  259.480011  261.899994  252.179993  255.169998   92352600
#
# [1528 rows x 5 columns]

# %%
data.head() # fonction pour voir les 5 premières lignes du dataset
data.tail() # fonction pour voir les 5 dernières ligne du dataset
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2026-01-26  255.410004  256.559998  249.800003  251.479996  55969200
# 2026-01-27  258.269989  261.950012  258.209991  259.170013  49648300
# 2026-01-28  256.440002  258.859985  254.509995  257.649994  41288000
# 2026-01-29  258.279999  259.649994  254.410004  258.000000  67253000
# 2026-01-30  259.480011  261.899994  252.179993  255.169998  92352600
